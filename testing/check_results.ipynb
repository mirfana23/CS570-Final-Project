# %%
import pickle
import pprint

path = 'results.pkl'
results = pickle.load(open(path, 'rb'))
pprint.pprint(results)
# Out:
# {('random', 3, 'fixed', 'mc_dropout', 'average', 0.0): {'Average f1 score': 0.01,
#                                                         'Average jaccard similarity': 0.0,
#                                                         'Average precision': 0.0,
#                                                         'Average recall': 0.01},
#  ('random', 3, 'fixed', 'mc_dropout', 'average', 0.1): {'Average f1 score': 0.0,
#                                                         'Average jaccard similarity': 0.0,
#                                                         'Average precision': 0.0,
#                                                         'Average recall': 0.0},
#  ('random', 3, 'fixed', 'mc_dropout', 'average', 0.2): {'Average f1 score': 0.0,
#                                                         'Average jaccard similarity': 0.0,
#                                                         'Average precision': 0.0,
# ...

# %%
import csv

data = {('random', 3, 'fixed', 'mc_dropout', 'average', 0.0): {'Average f1 score': 0.01,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.01},
 ('random', 3, 'fixed', 'mc_dropout', 'average', 0.1): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'average', 0.2): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'average', 0.3): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'average', 0.4): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'average', 0.5): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'average', 0.6): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'average', 0.7): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'average', 0.8): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.0): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.1): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.2): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.3): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.4): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.5): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.6): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.7): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_dropout', 'majority', 0.8): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.0): {'Average f1 score': 0.61,
                                                             'Average jaccard similarity': 0.54,
                                                             'Average precision': 0.58,
                                                             'Average recall': 0.71},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.1): {'Average f1 score': 0.62,
                                                             'Average jaccard similarity': 0.57,
                                                             'Average precision': 0.61,
                                                             'Average recall': 0.69},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.2): {'Average f1 score': 0.56,
                                                             'Average jaccard similarity': 0.5,
                                                             'Average precision': 0.56,
                                                             'Average recall': 0.62},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.3): {'Average f1 score': 0.55,
                                                             'Average jaccard similarity': 0.52,
                                                             'Average precision': 0.57,
                                                             'Average recall': 0.56},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.4): {'Average f1 score': 0.58,
                                                             'Average jaccard similarity': 0.56,
                                                             'Average precision': 0.61,
                                                             'Average recall': 0.59},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.5): {'Average f1 score': 0.53,
                                                             'Average jaccard similarity': 0.51,
                                                             'Average precision': 0.56,
                                                             'Average recall': 0.52},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.6): {'Average f1 score': 0.4,
                                                             'Average jaccard similarity': 0.39,
                                                             'Average precision': 0.41,
                                                             'Average recall': 0.4},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.7): {'Average f1 score': 0.44,
                                                             'Average jaccard similarity': 0.44,
                                                             'Average precision': 0.44,
                                                             'Average recall': 0.44},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.8): {'Average f1 score': 0.32,
                                                             'Average jaccard similarity': 0.32,
                                                             'Average precision': 0.32,
                                                             'Average recall': 0.32},
 ('random', 3, 'fixed', 'mc_perturbation', 'average', 0.9): {'Average f1 score': 0.24,
                                                             'Average jaccard similarity': 0.24,
                                                             'Average precision': 0.26,
                                                             'Average recall': 0.24},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.0): {'Average f1 score': 0.6,
                                                              'Average jaccard similarity': 0.54,
                                                              'Average precision': 0.57,
                                                              'Average recall': 0.71},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.1): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.2): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.3): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.4): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.5): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.6): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.7): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'fixed', 'mc_perturbation', 'majority', 0.8): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'fixed', 'naive', 'average', 0.0): {'Average f1 score': 0.72,
                                                   'Average jaccard similarity': 0.67,
                                                   'Average precision': 0.68,
                                                   'Average recall': 0.84},
 ('random', 3, 'fixed', 'naive', 'average', 0.1): {'Average f1 score': 0.66,
                                                   'Average jaccard similarity': 0.6,
                                                   'Average precision': 0.64,
                                                   'Average recall': 0.74},
 ('random', 3, 'fixed', 'naive', 'average', 0.2): {'Average f1 score': 0.72,
                                                   'Average jaccard similarity': 0.66,
                                                   'Average precision': 0.69,
                                                   'Average recall': 0.82},
 ('random', 3, 'fixed', 'naive', 'average', 0.3): {'Average f1 score': 0.66,
                                                   'Average jaccard similarity': 0.6,
                                                   'Average precision': 0.66,
                                                   'Average recall': 0.72},
 ('random', 3, 'fixed', 'naive', 'average', 0.4): {'Average f1 score': 0.77,
                                                   'Average jaccard similarity': 0.71,
                                                   'Average precision': 0.75,
                                                   'Average recall': 0.86},
 ('random', 3, 'fixed', 'naive', 'average', 0.5): {'Average f1 score': 0.72,
                                                   'Average jaccard similarity': 0.64,
                                                   'Average precision': 0.7,
                                                   'Average recall': 0.85},
 ('random', 3, 'fixed', 'naive', 'average', 0.6): {'Average f1 score': 0.72,
                                                   'Average jaccard similarity': 0.65,
                                                   'Average precision': 0.69,
                                                   'Average recall': 0.81},
 ('random', 3, 'fixed', 'naive', 'average', 0.7): {'Average f1 score': 0.76,
                                                   'Average jaccard similarity': 0.71,
                                                   'Average precision': 0.74,
                                                   'Average recall': 0.82},
 ('random', 3, 'fixed', 'naive', 'average', 0.8): {'Average f1 score': 0.69,
                                                   'Average jaccard similarity': 0.62,
                                                   'Average precision': 0.64,
                                                   'Average recall': 0.82},
 ('random', 3, 'fixed', 'naive', 'average', 0.9): {'Average f1 score': 0.73,
                                                   'Average jaccard similarity': 0.66,
                                                   'Average precision': 0.7,
                                                   'Average recall': 0.83},
 ('random', 3, 'fixed', 'naive', 'majority', 0.0): {'Average f1 score': 0.72,
                                                    'Average jaccard similarity': 0.66,
                                                    'Average precision': 0.7,
                                                    'Average recall': 0.82},
 ('random', 3, 'fixed', 'naive', 'majority', 0.1): {'Average f1 score': 0.75,
                                                    'Average jaccard similarity': 0.69,
                                                    'Average precision': 0.7,
                                                    'Average recall': 0.87},
 ('random', 3, 'fixed', 'naive', 'majority', 0.2): {'Average f1 score': 0.66,
                                                    'Average jaccard similarity': 0.6,
                                                    'Average precision': 0.64,
                                                    'Average recall': 0.76},
 ('random', 3, 'fixed', 'naive', 'majority', 0.3): {'Average f1 score': 0.61,
                                                    'Average jaccard similarity': 0.53,
                                                    'Average precision': 0.56,
                                                    'Average recall': 0.73},
 ('random', 3, 'fixed', 'naive', 'majority', 0.4): {'Average f1 score': 0.69,
                                                    'Average jaccard similarity': 0.63,
                                                    'Average precision': 0.68,
                                                    'Average recall': 0.78},
 ('random', 3, 'fixed', 'naive', 'majority', 0.5): {'Average f1 score': 0.7,
                                                    'Average jaccard similarity': 0.63,
                                                    'Average precision': 0.7,
                                                    'Average recall': 0.78},
 ('random', 3, 'fixed', 'naive', 'majority', 0.6): {'Average f1 score': 0.67,
                                                    'Average jaccard similarity': 0.61,
                                                    'Average precision': 0.63,
                                                    'Average recall': 0.8},
 ('random', 3, 'fixed', 'naive', 'majority', 0.7): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.62,
                                                    'Average precision': 0.66,
                                                    'Average recall': 0.74},
 ('random', 3, 'fixed', 'naive', 'majority', 0.8): {'Average f1 score': 0.7,
                                                    'Average jaccard similarity': 0.63,
                                                    'Average precision': 0.68,
                                                    'Average recall': 0.8},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.0): {'Average f1 score': 0.01,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.01,
                                                        'Average recall': 0.01},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.1): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.2): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.3): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.4): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.5): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.6): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.7): {'Average f1 score': 0.01,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.01,
                                                        'Average recall': 0.01},
 ('random', 3, 'range', 'mc_dropout', 'average', 0.8): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.0): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.1): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.2): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.3): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.4): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.5): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.6): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.7): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_dropout', 'majority', 0.8): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.0): {'Average f1 score': 0.58,
                                                             'Average jaccard similarity': 0.52,
                                                             'Average precision': 0.53,
                                                             'Average recall': 0.71},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.1): {'Average f1 score': 0.66,
                                                             'Average jaccard similarity': 0.62,
                                                             'Average precision': 0.65,
                                                             'Average recall': 0.7},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.2): {'Average f1 score': 0.59,
                                                             'Average jaccard similarity': 0.55,
                                                             'Average precision': 0.59,
                                                             'Average recall': 0.62},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.3): {'Average f1 score': 0.63,
                                                             'Average jaccard similarity': 0.6,
                                                             'Average precision': 0.63,
                                                             'Average recall': 0.67},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.4): {'Average f1 score': 0.63,
                                                             'Average jaccard similarity': 0.61,
                                                             'Average precision': 0.64,
                                                             'Average recall': 0.64},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.5): {'Average f1 score': 0.56,
                                                             'Average jaccard similarity': 0.55,
                                                             'Average precision': 0.56,
                                                             'Average recall': 0.57},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.6): {'Average f1 score': 0.48,
                                                             'Average jaccard similarity': 0.47,
                                                             'Average precision': 0.5,
                                                             'Average recall': 0.47},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.7): {'Average f1 score': 0.52,
                                                             'Average jaccard similarity': 0.5,
                                                             'Average precision': 0.54,
                                                             'Average recall': 0.51},
 ('random', 3, 'range', 'mc_perturbation', 'average', 0.8): {'Average f1 score': 0.38,
                                                             'Average jaccard similarity': 0.38,
                                                             'Average precision': 0.38,
                                                             'Average recall': 0.38},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.0): {'Average f1 score': 0.6,
                                                              'Average jaccard similarity': 0.52,
                                                              'Average precision': 0.55,
                                                              'Average recall': 0.73},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.1): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.2): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.3): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.4): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.5): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.6): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.7): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'range', 'mc_perturbation', 'majority', 0.8): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 3, 'range', 'naive', 'average', 0.0): {'Average f1 score': 0.76,
                                                   'Average jaccard similarity': 0.71,
                                                   'Average precision': 0.73,
                                                   'Average recall': 0.83},
 ('random', 3, 'range', 'naive', 'average', 0.1): {'Average f1 score': 0.71,
                                                   'Average jaccard similarity': 0.66,
                                                   'Average precision': 0.69,
                                                   'Average recall': 0.81},
 ('random', 3, 'range', 'naive', 'average', 0.2): {'Average f1 score': 0.76,
                                                   'Average jaccard similarity': 0.7,
                                                   'Average precision': 0.73,
                                                   'Average recall': 0.86},
 ('random', 3, 'range', 'naive', 'average', 0.3): {'Average f1 score': 0.73,
                                                   'Average jaccard similarity': 0.67,
                                                   'Average precision': 0.71,
                                                   'Average recall': 0.81},
 ('random', 3, 'range', 'naive', 'average', 0.4): {'Average f1 score': 0.64,
                                                   'Average jaccard similarity': 0.58,
                                                   'Average precision': 0.6,
                                                   'Average recall': 0.74},
 ('random', 3, 'range', 'naive', 'average', 0.5): {'Average f1 score': 0.71,
                                                   'Average jaccard similarity': 0.64,
                                                   'Average precision': 0.67,
                                                   'Average recall': 0.82},
 ('random', 3, 'range', 'naive', 'average', 0.6): {'Average f1 score': 0.77,
                                                   'Average jaccard similarity': 0.72,
                                                   'Average precision': 0.76,
                                                   'Average recall': 0.83},
 ('random', 3, 'range', 'naive', 'average', 0.7): {'Average f1 score': 0.74,
                                                   'Average jaccard similarity': 0.69,
                                                   'Average precision': 0.72,
                                                   'Average recall': 0.81},
 ('random', 3, 'range', 'naive', 'average', 0.8): {'Average f1 score': 0.68,
                                                   'Average jaccard similarity': 0.62,
                                                   'Average precision': 0.67,
                                                   'Average recall': 0.77},
 ('random', 3, 'range', 'naive', 'majority', 0.0): {'Average f1 score': 0.65,
                                                    'Average jaccard similarity': 0.58,
                                                    'Average precision': 0.63,
                                                    'Average recall': 0.74},
 ('random', 3, 'range', 'naive', 'majority', 0.1): {'Average f1 score': 0.65,
                                                    'Average jaccard similarity': 0.59,
                                                    'Average precision': 0.62,
                                                    'Average recall': 0.75},
 ('random', 3, 'range', 'naive', 'majority', 0.2): {'Average f1 score': 0.67,
                                                    'Average jaccard similarity': 0.6,
                                                    'Average precision': 0.63,
                                                    'Average recall': 0.77},
 ('random', 3, 'range', 'naive', 'majority', 0.3): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.63,
                                                    'Average precision': 0.66,
                                                    'Average recall': 0.75},
 ('random', 3, 'range', 'naive', 'majority', 0.4): {'Average f1 score': 0.65,
                                                    'Average jaccard similarity': 0.61,
                                                    'Average precision': 0.63,
                                                    'Average recall': 0.72},
 ('random', 3, 'range', 'naive', 'majority', 0.5): {'Average f1 score': 0.61,
                                                    'Average jaccard similarity': 0.54,
                                                    'Average precision': 0.57,
                                                    'Average recall': 0.73},
 ('random', 3, 'range', 'naive', 'majority', 0.6): {'Average f1 score': 0.71,
                                                    'Average jaccard similarity': 0.65,
                                                    'Average precision': 0.71,
                                                    'Average recall': 0.79},
 ('random', 3, 'range', 'naive', 'majority', 0.7): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.61,
                                                    'Average precision': 0.64,
                                                    'Average recall': 0.8},
 ('random', 3, 'range', 'naive', 'majority', 0.8): {'Average f1 score': 0.65,
                                                    'Average jaccard similarity': 0.58,
                                                    'Average precision': 0.62,
                                                    'Average recall': 0.75},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.0): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.1): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.2): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.3): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.4): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.5): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.6): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.7): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'average', 0.8): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.01,
                                                        'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.0): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.1): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.2): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.3): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.4): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.5): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.6): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.7): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_dropout', 'majority', 0.8): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.0): {'Average f1 score': 0.56,
                                                             'Average jaccard similarity': 0.49,
                                                             'Average precision': 0.5,
                                                             'Average recall': 0.71},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.1): {'Average f1 score': 0.6,
                                                             'Average jaccard similarity': 0.51,
                                                             'Average precision': 0.56,
                                                             'Average recall': 0.72},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.2): {'Average f1 score': 0.69,
                                                             'Average jaccard similarity': 0.64,
                                                             'Average precision': 0.67,
                                                             'Average recall': 0.78},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.3): {'Average f1 score': 0.64,
                                                             'Average jaccard similarity': 0.61,
                                                             'Average precision': 0.64,
                                                             'Average recall': 0.67},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.4): {'Average f1 score': 0.63,
                                                             'Average jaccard similarity': 0.61,
                                                             'Average precision': 0.64,
                                                             'Average recall': 0.65},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.5): {'Average f1 score': 0.59,
                                                             'Average jaccard similarity': 0.57,
                                                             'Average precision': 0.61,
                                                             'Average recall': 0.6},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.6): {'Average f1 score': 0.55,
                                                             'Average jaccard similarity': 0.54,
                                                             'Average precision': 0.56,
                                                             'Average recall': 0.56},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.7): {'Average f1 score': 0.63,
                                                             'Average jaccard similarity': 0.62,
                                                             'Average precision': 0.64,
                                                             'Average recall': 0.62},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.8): {'Average f1 score': 0.33,
                                                             'Average jaccard similarity': 0.33,
                                                             'Average precision': 0.34,
                                                             'Average recall': 0.33},
 ('random', 5, 'fixed', 'mc_perturbation', 'average', 0.9): {'Average f1 score': 0.3,
                                                             'Average jaccard similarity': 0.29,
                                                             'Average precision': 0.31,
                                                             'Average recall': 0.29},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.0): {'Average f1 score': 0.6,
                                                              'Average jaccard similarity': 0.52,
                                                              'Average precision': 0.55,
                                                              'Average recall': 0.77},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.1): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.2): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.3): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.4): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.5): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.6): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.7): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'fixed', 'mc_perturbation', 'majority', 0.8): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'fixed', 'naive', 'average', 0.0): {'Average f1 score': 0.74,
                                                   'Average jaccard similarity': 0.66,
                                                   'Average precision': 0.69,
                                                   'Average recall': 0.88},
 ('random', 5, 'fixed', 'naive', 'average', 0.1): {'Average f1 score': 0.7,
                                                   'Average jaccard similarity': 0.63,
                                                   'Average precision': 0.65,
                                                   'Average recall': 0.85},
 ('random', 5, 'fixed', 'naive', 'average', 0.2): {'Average f1 score': 0.68,
                                                   'Average jaccard similarity': 0.62,
                                                   'Average precision': 0.63,
                                                   'Average recall': 0.84},
 ('random', 5, 'fixed', 'naive', 'average', 0.3): {'Average f1 score': 0.66,
                                                   'Average jaccard similarity': 0.59,
                                                   'Average precision': 0.62,
                                                   'Average recall': 0.79},
 ('random', 5, 'fixed', 'naive', 'average', 0.4): {'Average f1 score': 0.7,
                                                   'Average jaccard similarity': 0.61,
                                                   'Average precision': 0.65,
                                                   'Average recall': 0.86},
 ('random', 5, 'fixed', 'naive', 'average', 0.5): {'Average f1 score': 0.67,
                                                   'Average jaccard similarity': 0.59,
                                                   'Average precision': 0.62,
                                                   'Average recall': 0.83},
 ('random', 5, 'fixed', 'naive', 'average', 0.6): {'Average f1 score': 0.66,
                                                   'Average jaccard similarity': 0.58,
                                                   'Average precision': 0.6,
                                                   'Average recall': 0.82},
 ('random', 5, 'fixed', 'naive', 'average', 0.7): {'Average f1 score': 0.75,
                                                   'Average jaccard similarity': 0.68,
                                                   'Average precision': 0.73,
                                                   'Average recall': 0.84},
 ('random', 5, 'fixed', 'naive', 'average', 0.8): {'Average f1 score': 0.72,
                                                   'Average jaccard similarity': 0.65,
                                                   'Average precision': 0.66,
                                                   'Average recall': 0.88},
 ('random', 5, 'fixed', 'naive', 'average', 0.9): {'Average f1 score': 0.62,
                                                   'Average jaccard similarity': 0.54,
                                                   'Average precision': 0.56,
                                                   'Average recall': 0.78},
 ('random', 5, 'fixed', 'naive', 'majority', 0.0): {'Average f1 score': 0.67,
                                                    'Average jaccard similarity': 0.58,
                                                    'Average precision': 0.61,
                                                    'Average recall': 0.84},
 ('random', 5, 'fixed', 'naive', 'majority', 0.1): {'Average f1 score': 0.73,
                                                    'Average jaccard similarity': 0.65,
                                                    'Average precision': 0.67,
                                                    'Average recall': 0.88},
 ('random', 5, 'fixed', 'naive', 'majority', 0.2): {'Average f1 score': 0.72,
                                                    'Average jaccard similarity': 0.66,
                                                    'Average precision': 0.68,
                                                    'Average recall': 0.88},
 ('random', 5, 'fixed', 'naive', 'majority', 0.3): {'Average f1 score': 0.7,
                                                    'Average jaccard similarity': 0.63,
                                                    'Average precision': 0.66,
                                                    'Average recall': 0.83},
 ('random', 5, 'fixed', 'naive', 'majority', 0.4): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.6,
                                                    'Average precision': 0.65,
                                                    'Average recall': 0.79},
 ('random', 5, 'fixed', 'naive', 'majority', 0.5): {'Average f1 score': 0.69,
                                                    'Average jaccard similarity': 0.61,
                                                    'Average precision': 0.64,
                                                    'Average recall': 0.85},
 ('random', 5, 'fixed', 'naive', 'majority', 0.6): {'Average f1 score': 0.69,
                                                    'Average jaccard similarity': 0.62,
                                                    'Average precision': 0.64,
                                                    'Average recall': 0.86},
 ('random', 5, 'fixed', 'naive', 'majority', 0.7): {'Average f1 score': 0.69,
                                                    'Average jaccard similarity': 0.63,
                                                    'Average precision': 0.65,
                                                    'Average recall': 0.81},
 ('random', 5, 'fixed', 'naive', 'majority', 0.8): {'Average f1 score': 0.72,
                                                    'Average jaccard similarity': 0.65,
                                                    'Average precision': 0.7,
                                                    'Average recall': 0.84},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.0): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.1): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.2): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.01},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.3): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.4): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.5): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.6): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.7): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'average', 0.8): {'Average f1 score': 0.0,
                                                        'Average jaccard similarity': 0.0,
                                                        'Average precision': 0.0,
                                                        'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.0): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.1): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.2): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.3): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.4): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.5): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.6): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.7): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_dropout', 'majority', 0.8): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.0): {'Average f1 score': 0.59,
                                                             'Average jaccard similarity': 0.5,
                                                             'Average precision': 0.53,
                                                             'Average recall': 0.77},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.1): {'Average f1 score': 0.61,
                                                             'Average jaccard similarity': 0.51,
                                                             'Average precision': 0.53,
                                                             'Average recall': 0.82},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.2): {'Average f1 score': 0.68,
                                                             'Average jaccard similarity': 0.63,
                                                             'Average precision': 0.67,
                                                             'Average recall': 0.74},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.3): {'Average f1 score': 0.62,
                                                             'Average jaccard similarity': 0.58,
                                                             'Average precision': 0.63,
                                                             'Average recall': 0.67},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.4): {'Average f1 score': 0.69,
                                                             'Average jaccard similarity': 0.67,
                                                             'Average precision': 0.71,
                                                             'Average recall': 0.7},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.5): {'Average f1 score': 0.52,
                                                             'Average jaccard similarity': 0.51,
                                                             'Average precision': 0.54,
                                                             'Average recall': 0.52},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.6): {'Average f1 score': 0.58,
                                                             'Average jaccard similarity': 0.56,
                                                             'Average precision': 0.61,
                                                             'Average recall': 0.57},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.7): {'Average f1 score': 0.47,
                                                             'Average jaccard similarity': 0.46,
                                                             'Average precision': 0.48,
                                                             'Average recall': 0.46},
 ('random', 5, 'range', 'mc_perturbation', 'average', 0.8): {'Average f1 score': 0.38,
                                                             'Average jaccard similarity': 0.38,
                                                             'Average precision': 0.39,
                                                             'Average recall': 0.38},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.0): {'Average f1 score': 0.55,
                                                              'Average jaccard similarity': 0.45,
                                                              'Average precision': 0.47,
                                                              'Average recall': 0.75},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.1): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.2): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.3): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.4): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.5): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.6): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.7): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'range', 'mc_perturbation', 'majority', 0.8): {'Average f1 score': 0.0,
                                                              'Average jaccard similarity': 0.0,
                                                              'Average precision': 0.0,
                                                              'Average recall': 0.0},
 ('random', 5, 'range', 'naive', 'average', 0.0): {'Average f1 score': 0.74,
                                                   'Average jaccard similarity': 0.68,
                                                   'Average precision': 0.7,
                                                   'Average recall': 0.87},
 ('random', 5, 'range', 'naive', 'average', 0.1): {'Average f1 score': 0.63,
                                                   'Average jaccard similarity': 0.56,
                                                   'Average precision': 0.58,
                                                   'Average recall': 0.8},
 ('random', 5, 'range', 'naive', 'average', 0.2): {'Average f1 score': 0.71,
                                                   'Average jaccard similarity': 0.62,
                                                   'Average precision': 0.65,
                                                   'Average recall': 0.86},
 ('random', 5, 'range', 'naive', 'average', 0.3): {'Average f1 score': 0.7,
                                                   'Average jaccard similarity': 0.62,
                                                   'Average precision': 0.67,
                                                   'Average recall': 0.85},
 ('random', 5, 'range', 'naive', 'average', 0.4): {'Average f1 score': 0.66,
                                                   'Average jaccard similarity': 0.58,
                                                   'Average precision': 0.62,
                                                   'Average recall': 0.79},
 ('random', 5, 'range', 'naive', 'average', 0.5): {'Average f1 score': 0.7,
                                                   'Average jaccard similarity': 0.63,
                                                   'Average precision': 0.65,
                                                   'Average recall': 0.87},
 ('random', 5, 'range', 'naive', 'average', 0.6): {'Average f1 score': 0.63,
                                                   'Average jaccard similarity': 0.55,
                                                   'Average precision': 0.58,
                                                   'Average recall': 0.78},
 ('random', 5, 'range', 'naive', 'average', 0.7): {'Average f1 score': 0.7,
                                                   'Average jaccard similarity': 0.63,
                                                   'Average precision': 0.66,
                                                   'Average recall': 0.84},
 ('random', 5, 'range', 'naive', 'average', 0.8): {'Average f1 score': 0.7,
                                                   'Average jaccard similarity': 0.63,
                                                   'Average precision': 0.65,
                                                   'Average recall': 0.83},
 ('random', 5, 'range', 'naive', 'majority', 0.0): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.6,
                                                    'Average precision': 0.64,
                                                    'Average recall': 0.8},
 ('random', 5, 'range', 'naive', 'majority', 0.1): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.6,
                                                    'Average precision': 0.63,
                                                    'Average recall': 0.84},
 ('random', 5, 'range', 'naive', 'majority', 0.2): {'Average f1 score': 0.71,
                                                    'Average jaccard similarity': 0.63,
                                                    'Average precision': 0.65,
                                                    'Average recall': 0.87},
 ('random', 5, 'range', 'naive', 'majority', 0.3): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.6,
                                                    'Average precision': 0.63,
                                                    'Average recall': 0.82},
 ('random', 5, 'range', 'naive', 'majority', 0.4): {'Average f1 score': 0.7,
                                                    'Average jaccard similarity': 0.63,
                                                    'Average precision': 0.65,
                                                    'Average recall': 0.85},
 ('random', 5, 'range', 'naive', 'majority', 0.5): {'Average f1 score': 0.66,
                                                    'Average jaccard similarity': 0.58,
                                                    'Average precision': 0.6,
                                                    'Average recall': 0.81},
 ('random', 5, 'range', 'naive', 'majority', 0.6): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.61,
                                                    'Average precision': 0.63,
                                                    'Average recall': 0.83},
 ('random', 5, 'range', 'naive', 'majority', 0.7): {'Average f1 score': 0.63,
                                                    'Average jaccard similarity': 0.56,
                                                    'Average precision': 0.6,
                                                    'Average recall': 0.78},
 ('random', 5, 'range', 'naive', 'majority', 0.8): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.6,
                                                    'Average precision': 0.65,
                                                    'Average recall': 0.81},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.0): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.1): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.2): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.3): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.01},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.4): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.5): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.6): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.7): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'average', 0.8): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.0): {'Average f1 score': 0.01,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.03},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.1): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.2): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.3): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.4): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.5): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.6): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.7): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_dropout', 'majority', 0.8): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.0): {'Average f1 score': 0.57,
                                                              'Average jaccard similarity': 0.48,
                                                              'Average precision': 0.49,
                                                              'Average recall': 0.81},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.1): {'Average f1 score': 0.63,
                                                              'Average jaccard similarity': 0.53,
                                                              'Average precision': 0.55,
                                                              'Average recall': 0.85},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.2): {'Average f1 score': 0.71,
                                                              'Average jaccard similarity': 0.66,
                                                              'Average precision': 0.68,
                                                              'Average recall': 0.82},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.3): {'Average f1 score': 0.63,
                                                              'Average jaccard similarity': 0.59,
                                                              'Average precision': 0.62,
                                                              'Average recall': 0.69},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.4): {'Average f1 score': 0.65,
                                                              'Average jaccard similarity': 0.62,
                                                              'Average precision': 0.65,
                                                              'Average recall': 0.68},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.5): {'Average f1 score': 0.68,
                                                              'Average jaccard similarity': 0.65,
                                                              'Average precision': 0.69,
                                                              'Average recall': 0.7},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.6): {'Average f1 score': 0.69,
                                                              'Average jaccard similarity': 0.68,
                                                              'Average precision': 0.7,
                                                              'Average recall': 0.69},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.7): {'Average f1 score': 0.58,
                                                              'Average jaccard similarity': 0.57,
                                                              'Average precision': 0.6,
                                                              'Average recall': 0.58},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.8): {'Average f1 score': 0.48,
                                                              'Average jaccard similarity': 0.47,
                                                              'Average precision': 0.49,
                                                              'Average recall': 0.47},
 ('random', 10, 'fixed', 'mc_perturbation', 'average', 0.9): {'Average f1 score': 0.43,
                                                              'Average jaccard similarity': 0.43,
                                                              'Average precision': 0.44,
                                                              'Average recall': 0.43},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.0): {'Average f1 score': 0.57,
                                                               'Average jaccard similarity': 0.48,
                                                               'Average precision': 0.5,
                                                               'Average recall': 0.82},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.1): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.2): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.3): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.4): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.5): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.6): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.7): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'fixed', 'mc_perturbation', 'majority', 0.8): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'fixed', 'naive', 'average', 0.0): {'Average f1 score': 0.63,
                                                    'Average jaccard similarity': 0.54,
                                                    'Average precision': 0.56,
                                                    'Average recall': 0.9},
 ('random', 10, 'fixed', 'naive', 'average', 0.1): {'Average f1 score': 0.64,
                                                    'Average jaccard similarity': 0.56,
                                                    'Average precision': 0.57,
                                                    'Average recall': 0.88},
 ('random', 10, 'fixed', 'naive', 'average', 0.2): {'Average f1 score': 0.63,
                                                    'Average jaccard similarity': 0.54,
                                                    'Average precision': 0.57,
                                                    'Average recall': 0.87},
 ('random', 10, 'fixed', 'naive', 'average', 0.3): {'Average f1 score': 0.65,
                                                    'Average jaccard similarity': 0.55,
                                                    'Average precision': 0.56,
                                                    'Average recall': 0.89},
 ('random', 10, 'fixed', 'naive', 'average', 0.4): {'Average f1 score': 0.63,
                                                    'Average jaccard similarity': 0.56,
                                                    'Average precision': 0.57,
                                                    'Average recall': 0.82},
 ('random', 10, 'fixed', 'naive', 'average', 0.5): {'Average f1 score': 0.61,
                                                    'Average jaccard similarity': 0.53,
                                                    'Average precision': 0.55,
                                                    'Average recall': 0.82},
 ('random', 10, 'fixed', 'naive', 'average', 0.6): {'Average f1 score': 0.66,
                                                    'Average jaccard similarity': 0.57,
                                                    'Average precision': 0.58,
                                                    'Average recall': 0.91},
 ('random', 10, 'fixed', 'naive', 'average', 0.7): {'Average f1 score': 0.66,
                                                    'Average jaccard similarity': 0.57,
                                                    'Average precision': 0.6,
                                                    'Average recall': 0.88},
 ('random', 10, 'fixed', 'naive', 'average', 0.8): {'Average f1 score': 0.61,
                                                    'Average jaccard similarity': 0.53,
                                                    'Average precision': 0.56,
                                                    'Average recall': 0.81},
 ('random', 10, 'fixed', 'naive', 'average', 0.9): {'Average f1 score': 0.64,
                                                    'Average jaccard similarity': 0.55,
                                                    'Average precision': 0.56,
                                                    'Average recall': 0.89},
 ('random', 10, 'fixed', 'naive', 'majority', 0.0): {'Average f1 score': 0.63,
                                                     'Average jaccard similarity': 0.55,
                                                     'Average precision': 0.55,
                                                     'Average recall': 0.86},
 ('random', 10, 'fixed', 'naive', 'majority', 0.1): {'Average f1 score': 0.59,
                                                     'Average jaccard similarity': 0.49,
                                                     'Average precision': 0.52,
                                                     'Average recall': 0.83},
 ('random', 10, 'fixed', 'naive', 'majority', 0.2): {'Average f1 score': 0.67,
                                                     'Average jaccard similarity': 0.58,
                                                     'Average precision': 0.6,
                                                     'Average recall': 0.92},
 ('random', 10, 'fixed', 'naive', 'majority', 0.3): {'Average f1 score': 0.64,
                                                     'Average jaccard similarity': 0.55,
                                                     'Average precision': 0.57,
                                                     'Average recall': 0.87},
 ('random', 10, 'fixed', 'naive', 'majority', 0.4): {'Average f1 score': 0.61,
                                                     'Average jaccard similarity': 0.52,
                                                     'Average precision': 0.53,
                                                     'Average recall': 0.84},
 ('random', 10, 'fixed', 'naive', 'majority', 0.5): {'Average f1 score': 0.68,
                                                     'Average jaccard similarity': 0.61,
                                                     'Average precision': 0.63,
                                                     'Average recall': 0.87},
 ('random', 10, 'fixed', 'naive', 'majority', 0.6): {'Average f1 score': 0.59,
                                                     'Average jaccard similarity': 0.49,
                                                     'Average precision': 0.51,
                                                     'Average recall': 0.88},
 ('random', 10, 'fixed', 'naive', 'majority', 0.7): {'Average f1 score': 0.66,
                                                     'Average jaccard similarity': 0.58,
                                                     'Average precision': 0.58,
                                                     'Average recall': 0.86},
 ('random', 10, 'fixed', 'naive', 'majority', 0.8): {'Average f1 score': 0.67,
                                                     'Average jaccard similarity': 0.59,
                                                     'Average precision': 0.6,
                                                     'Average recall': 0.88},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.0): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.1): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.2): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.3): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.4): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.5): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.6): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.7): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'average', 0.8): {'Average f1 score': 0.0,
                                                         'Average jaccard similarity': 0.0,
                                                         'Average precision': 0.0,
                                                         'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.0): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.01},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.1): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.2): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.3): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.4): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.5): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.6): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.7): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'range', 'mc_dropout', 'majority', 0.8): {'Average f1 score': 0.0,
                                                          'Average jaccard similarity': 0.0,
                                                          'Average precision': 0.0,
                                                          'Average recall': 0.0},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.0): {'Average f1 score': 0.58,
                                                              'Average jaccard similarity': 0.49,
                                                              'Average precision': 0.49,
                                                              'Average recall': 0.87},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.1): {'Average f1 score': 0.57,
                                                              'Average jaccard similarity': 0.47,
                                                              'Average precision': 0.49,
                                                              'Average recall': 0.81},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.2): {'Average f1 score': 0.63,
                                                              'Average jaccard similarity': 0.57,
                                                              'Average precision': 0.6,
                                                              'Average recall': 0.75},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.3): {'Average f1 score': 0.66,
                                                              'Average jaccard similarity': 0.61,
                                                              'Average precision': 0.64,
                                                              'Average recall': 0.74},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.4): {'Average f1 score': 0.6,
                                                              'Average jaccard similarity': 0.57,
                                                              'Average precision': 0.6,
                                                              'Average recall': 0.65},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.5): {'Average f1 score': 0.62,
                                                              'Average jaccard similarity': 0.6,
                                                              'Average precision': 0.64,
                                                              'Average recall': 0.63},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.6): {'Average f1 score': 0.62,
                                                              'Average jaccard similarity': 0.6,
                                                              'Average precision': 0.63,
                                                              'Average recall': 0.62},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.7): {'Average f1 score': 0.6,
                                                              'Average jaccard similarity': 0.59,
                                                              'Average precision': 0.61,
                                                              'Average recall': 0.61},
 ('random', 10, 'range', 'mc_perturbation', 'average', 0.8): {'Average f1 score': 0.45,
                                                              'Average jaccard similarity': 0.45,
                                                              'Average precision': 0.45,
                                                              'Average recall': 0.45},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.0): {'Average f1 score': 0.53,
                                                               'Average jaccard similarity': 0.42,
                                                               'Average precision': 0.43,
                                                               'Average recall': 0.88},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.1): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.2): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.3): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.4): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.5): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.6): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.7): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'range', 'mc_perturbation', 'majority', 0.8): {'Average f1 score': 0.0,
                                                               'Average jaccard similarity': 0.0,
                                                               'Average precision': 0.0,
                                                               'Average recall': 0.0},
 ('random', 10, 'range', 'naive', 'average', 0.0): {'Average f1 score': 0.65,
                                                    'Average jaccard similarity': 0.57,
                                                    'Average precision': 0.57,
                                                    'Average recall': 0.89},
 ('random', 10, 'range', 'naive', 'average', 0.1): {'Average f1 score': 0.59,
                                                    'Average jaccard similarity': 0.51,
                                                    'Average precision': 0.53,
                                                    'Average recall': 0.81},
 ('random', 10, 'range', 'naive', 'average', 0.2): {'Average f1 score': 0.65,
                                                    'Average jaccard similarity': 0.57,
                                                    'Average precision': 0.58,
                                                    'Average recall': 0.89},
 ('random', 10, 'range', 'naive', 'average', 0.3): {'Average f1 score': 0.62,
                                                    'Average jaccard similarity': 0.53,
                                                    'Average precision': 0.55,
                                                    'Average recall': 0.82},
 ('random', 10, 'range', 'naive', 'average', 0.4): {'Average f1 score': 0.68,
                                                    'Average jaccard similarity': 0.59,
                                                    'Average precision': 0.6,
                                                    'Average recall': 0.92},
 ('random', 10, 'range', 'naive', 'average', 0.5): {'Average f1 score': 0.64,
                                                    'Average jaccard similarity': 0.55,
                                                    'Average precision': 0.59,
                                                    'Average recall': 0.86},
 ('random', 10, 'range', 'naive', 'average', 0.6): {'Average f1 score': 0.59,
                                                    'Average jaccard similarity': 0.5,
                                                    'Average precision': 0.53,
                                                    'Average recall': 0.81},
 ('random', 10, 'range', 'naive', 'average', 0.7): {'Average f1 score': 0.62,
                                                    'Average jaccard similarity': 0.52,
                                                    'Average precision': 0.53,
                                                    'Average recall': 0.89},
 ('random', 10, 'range', 'naive', 'average', 0.8): {'Average f1 score': 0.64,
                                                    'Average jaccard similarity': 0.56,
                                                    'Average precision': 0.57,
                                                    'Average recall': 0.88},
 ('random', 10, 'range', 'naive', 'majority', 0.0): {'Average f1 score': 0.6,
                                                     'Average jaccard similarity': 0.5,
                                                     'Average precision': 0.52,
                                                     'Average recall': 0.88},
 ('random', 10, 'range', 'naive', 'majority', 0.1): {'Average f1 score': 0.61,
                                                     'Average jaccard similarity': 0.51,
                                                     'Average precision': 0.53,
                                                     'Average recall': 0.87},
 ('random', 10, 'range', 'naive', 'majority', 0.2): {'Average f1 score': 0.61,
                                                     'Average jaccard similarity': 0.51,
                                                     'Average precision': 0.53,
                                                     'Average recall': 0.87},
 ('random', 10, 'range', 'naive', 'majority', 0.3): {'Average f1 score': 0.6,
                                                     'Average jaccard similarity': 0.5,
                                                     'Average precision': 0.51,
                                                     'Average recall': 0.89},
 ('random', 10, 'range', 'naive', 'majority', 0.4): {'Average f1 score': 0.63,
                                                     'Average jaccard similarity': 0.53,
                                                     'Average precision': 0.55,
                                                     'Average recall': 0.89},
 ('random', 10, 'range', 'naive', 'majority', 0.5): {'Average f1 score': 0.6,
                                                     'Average jaccard similarity': 0.5,
                                                     'Average precision': 0.54,
                                                     'Average recall': 0.81},
 ('random', 10, 'range', 'naive', 'majority', 0.6): {'Average f1 score': 0.58,
                                                     'Average jaccard similarity': 0.48,
                                                     'Average precision': 0.51,
                                                     'Average recall': 0.82},
 ('random', 10, 'range', 'naive', 'majority', 0.7): {'Average f1 score': 0.64,
                                                     'Average jaccard similarity': 0.56,
                                                     'Average precision': 0.58,
                                                     'Average recall': 0.83},
 ('random', 10, 'range', 'naive', 'majority', 0.8): {'Average f1 score': 0.61,
                                                     'Average jaccard similarity': 0.52,
                                                     'Average precision': 0.55,
                                                     'Average recall': 0.81},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.0): {'Average f1 score': 0.5,
                                                              'Average jaccard similarity': 0.41,
                                                              'Average precision': 0.41,
                                                              'Average recall': 0.84},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.1): {'Average f1 score': 0.56,
                                                              'Average jaccard similarity': 0.46,
                                                              'Average precision': 0.47,
                                                              'Average recall': 0.87},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.2): {'Average f1 score': 0.58,
                                                              'Average jaccard similarity': 0.5,
                                                              'Average precision': 0.51,
                                                              'Average recall': 0.81},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.3): {'Average f1 score': 0.72,
                                                              'Average jaccard similarity': 0.65,
                                                              'Average precision': 0.68,
                                                              'Average recall': 0.83},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.4): {'Average f1 score': 0.67,
                                                              'Average jaccard similarity': 0.61,
                                                              'Average precision': 0.65,
                                                              'Average recall': 0.74},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.5): {'Average f1 score': 0.59,
                                                              'Average jaccard similarity': 0.57,
                                                              'Average precision': 0.6,
                                                              'Average recall': 0.62},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.6): {'Average f1 score': 0.6,
                                                              'Average jaccard similarity': 0.58,
                                                              'Average precision': 0.61,
                                                              'Average recall': 0.6},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.7): {'Average f1 score': 0.54,
                                                              'Average jaccard similarity': 0.52,
                                                              'Average precision': 0.55,
                                                              'Average recall': 0.55},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.8): {'Average f1 score': 0.52,
                                                              'Average jaccard similarity': 0.51,
                                                              'Average precision': 0.53,
                                                              'Average recall': 0.54},
 ('random', 20, 'fixed', 'mc_perturbation', 'average', 0.9): {'Average f1 score': 0.37,
                                                              'Average jaccard similarity': 0.37,
                                                              'Average precision': 0.38,
                                                              'Average recall': 0.37},
 ('random', 20, 'fixed', 'naive', 'average', 0.0): {'Average f1 score': 0.53,
                                                    'Average jaccard similarity': 0.43,
                                                    'Average precision': 0.45,
                                                    'Average recall': 0.85},
 ('random', 20, 'fixed', 'naive', 'average', 0.1): {'Average f1 score': 0.58,
                                                    'Average jaccard similarity': 0.49,
                                                    'Average precision': 0.5,
                                                    'Average recall': 0.89},
 ('random', 20, 'fixed', 'naive', 'average', 0.2): {'Average f1 score': 0.55,
                                                    'Average jaccard similarity': 0.45,
                                                    'Average precision': 0.46,
                                                    'Average recall': 0.89},
 ('random', 20, 'fixed', 'naive', 'average', 0.3): {'Average f1 score': 0.54,
                                                    'Average jaccard similarity': 0.44,
                                                    'Average precision': 0.45,
                                                    'Average recall': 0.89},
 ('random', 20, 'fixed', 'naive', 'average', 0.4): {'Average f1 score': 0.66,
                                                    'Average jaccard similarity': 0.56,
                                                    'Average precision': 0.57,
                                                    'Average recall': 0.94},
 ('random', 20, 'fixed', 'naive', 'average', 0.5): {'Average f1 score': 0.59,
                                                    'Average jaccard similarity': 0.48,
                                                    'Average precision': 0.49,
                                                    'Average recall': 0.93},
 ('random', 20, 'fixed', 'naive', 'average', 0.6): {'Average f1 score': 0.58,
                                                    'Average jaccard similarity': 0.48,
                                                    'Average precision': 0.49,
                                                    'Average recall': 0.87},
 ('random', 20, 'fixed', 'naive', 'average', 0.7): {'Average f1 score': 0.53,
                                                    'Average jaccard similarity': 0.43,
                                                    'Average precision': 0.45,
                                                    'Average recall': 0.86},
 ('random', 20, 'fixed', 'naive', 'average', 0.8): {'Average f1 score': 0.6,
                                                    'Average jaccard similarity': 0.49,
                                                    'Average precision': 0.51,
                                                    'Average recall': 0.94},
 ('random', 20, 'fixed', 'naive', 'average', 0.9): {'Average f1 score': 0.59,
                                                    'Average jaccard similarity': 0.49,
                                                    'Average precision': 0.52,
                                                    'Average recall': 0.86}}
    # Add the rest of the data here
    # ...


# Open the CSV file in write mode
with open('data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)

    # Write the column headers
    writer.writerow(['Method', 'Num Crop', 'Crop Size', 'Confidence', 'Logit Aggr', 'Threshold',
                     'Average f1 score', 'Average jaccard similarity'])

    # Write the data rows
    for key, values in data.items():
        row = list(key) + [values['Average f1 score'], values['Average jaccard similarity']]
        writer.writerow(row)
